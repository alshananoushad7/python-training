# %% [markdown]
# <a href="https://colab.research.google.com/github/alshananoushad7/python-training/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
k=int(input())
j=int(input())
m=int(input())
p=int(input())
if n<=0 or k<=0 or j<=0 or m<0 or p<0:
  print("invaild input")
else:
 n=n-(m//k + p//j)
 if m%k!=0 or p%j!=0:
  n=n-1
print("monkeyleft on tree:",n)
# Out:
# 20
# 2
# 3
# 13
# 13
# monkeyleft on tree: 9

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
a=a+b
b=a-b
a=a-b
print("a=",a)
print("b=",b)
# Out:
# enter a number:4
# enter a number:2
# a= 2
# b= 4

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
a=a^b
b=a^b
a=a^b
print("a=",a)
print("b=",b)
# Out:
# enter a number:3
# enter a number:2
# a= 2
# b= 3

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
temp=a
a=b
b=temp
print("a=",a)
print("b=",b)
# Out:
# enter a number:3
# enter a number:4
# a= 4
# b= 3

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# enter a number:4
# enter a number:5
# a= 5
# b= 4

# %%
N=10
K=5
candies=N
order=int(input())
while order<=candies:
  candies=candies-order
  print("number of candies sold:",order)
  print("number of candies available:",candies)
  while candies<=K:
    candies=N
    print("Number of candies available:",candies)
    break
  order=int(input())
while order>candies:
  print("invaild input")
  break
# Out:
# 3
# number of candies sold: 3
# number of candies available: 7
