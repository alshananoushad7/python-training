# %% [markdown]
# <a href="https://colab.research.google.com/github/alshananoushad7/python-training/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n= input("Enter a number: ")

if n== n[::-1]:
    print(n, "is a Palindrome")
else:
    print(n, "is not a Palindrome")
# Out:
# Enter a number: 333
# 333 is a Palindrome

# %%
n=(input("enter a string:"))
reverse=n[::-1]
print("reverse string:",reverse)
# Out:
# enter a string:1234
# reverse string: 4321

# %%
n=int(input("Enter a no.: "))
r=0
while n>0:
  a=n%10
  r=r*10+a
  n=n//10
print(r)
# Out:
# Enter a no.: 12
# 21

# %%
n=int(input("enter a number"))
sum=0
while n>0:
  sum+=n%10
  n=n//10
print(sum)
# Out:
# enter a number3
# 3

# %%
n=int(input("Enter a number: "))
s=0
while n>0:
  a=n%10
  if a>s:
    s=a
  n=n//10
print("Largest digit: ",s)
# Out:
# Enter a number: 123
# Largest digit:  3

# %%
n=(input("enter a string:"))
op=n[::-1]
if (n==op):
    print("palindrome")
else:
    print("not a palindrome")
# Out:
# enter a string:malayalam
# palindrome

# %%
a=input("Enter the string 1 : ")
b=input("Enter the string 2 : ")
if(sorted(a)==sorted(b)):
  print("anagram")
else:
  print("not anagram")
# Out:
# Enter the string 1 : aara
# Enter the string 2 : raaa
# anagram

# %%
print("CHARACTER COUNT WITHOUT BUILT IN")
a=input("Enter your string:")
count=0
for char in a:
  count=count+1
print("Count of characters is:",count)

print("CHARACTER COUNT WITH BUIT IN")
string=input("Enter your string:")
for char in string:
  length=len(string)
print("count of characters is:",length)
# Out:
# CHARACTER COUNT WITHOUT BUILT IN
# Enter your string:2354
# Count of characters is: 4
# CHARACTER COUNT WITH BUIT IN
# Enter your string:456
# count of characters is: 3

# %%
s=input("Enter the string: ")
result=""
for char in s:
  if char not in result:
    result+=char
print("After removing duplicates =",result)
# Out:
# Enter the string: 234
# After removing duplicates = 234

# %%
s=input("Ënter a string:")
v=0
c=0
for i in s:
  if(i in "aeiouAEIOU"):
    v+=1
  else:
    c+=1
print("No. of vowels:",v)
print("No of consonants:",c)
# Out:
# Ënter a string:alshana
# No. of vowels: 3
# No of consonants: 4

# %%
a=input("Ënter a string:")
s=""
for i in a:
  if(i!=" "):
    s+=i
print(s)
# Out:
# Ënter a string:123
# 123

# %%
a=[]
b=[]
N1=int(input("enter the value of N1:"))
N2=int(input("enter the value of N2:"))
a=list(map(int, input("Enter the elements: ").split()))
b=list(map(int, input("Enter the elements: ").split()))
x=sorted(set(a + b))
l=len(x)
if l%2 != 0:
  print("op=",x[l//2])
else:
  print("op=",(x[l//2-1]+x[l//2])/2)
# Out:
# enter the value of N1:2
# enter the value of N2:3
# Enter the elements: 1234
# Enter the elements: 12345
# op= 6789.5

# %%
n=int(input("Enter number:"))
a=bin(n)
b=a[2:]
b=b.replace('0','y').replace('1','0').replace('y','1')
print(int(b,2))
# Out:
# Enter number:23
# 8
